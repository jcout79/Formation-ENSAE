# %% [markdown]
# # Importation et nettoyage

# %% [markdown]
# Ce fichier est un début, à vous de l'amender et le mettre à votre sauce

# %%
import pandas as pd
don = pd.read_table("https://regression-avec-python.github.io/donnees/ozone.txt", header=0, sep=";")
don.head(3)
# Out:
#    sbp  tobacco   ldl  adiposity  famhist  typea  obesity  alcohol  age  chd
# 0  160    12.00  5.73      23.11  Present     49    25.30    97.20   52    1
# 1  144     0.01  4.41      28.61   Absent     55    28.87     2.06   63    1
# 2  118     0.08  3.48      32.28  Present     52    29.14     3.81   46    0

# %% [markdown]
# La colonne Date n'est pas une variable donc on l'enlève du dataframe

# %%
don = don.drop(columns=["Date"])
don.head(3)
# Out:
#      O3   T12   T15  Ne12  N12  S12  E12  W12     Vx    O3v    nebu  vent
# 0  63.6  13.4  15.0     7    0    0    3    0   9.35   95.6   NUAGE   EST
# 1  89.6  15.0  15.7     4    3    0    0    0   5.40  100.2  SOLEIL  NORD
# 2  79.0   7.9  10.1     8    0    0    7    0  19.30  105.6   NUAGE   EST

# %% [markdown]
# Je renomme la variable d'intérêt Y, je mets en général les X d'un côté et je regarde les types de variables afin de recoder les variables qualitatives

# %%
don = don.rename(columns={"chd":"Y"})
X = don.drop(columns=["Y"])
Y = don.filter(["Y"])

# %%
Xquanti = X.select_dtypes(exclude=['object'])
Xquali = X.select_dtypes(include=['object'])
print(Xquanti.head(3))
print(Xquali.head(3))
# Out:
#    sbp  tobacco   ldl  adiposity  typea  obesity  alcohol  age
# 0  160    12.00  5.73      23.11     49    25.30    97.20   52
# 1  144     0.01  4.41      28.61     55    28.87     2.06   63
# 2  118     0.08  3.48      32.28     52    29.14     3.81   46
#    famhist
# 0  Present
# 1   Absent
# 2  Present

# %% [markdown]
# Je vais recoder les variables qualitatives avec get_dummies de pd

# %%
XqualiD = pd.get_dummies(Xquali,drop_first=True,dtype=float)
XqualiD.head(3)
# Out:
#    famhist_Present
# 0              1.0
# 1              0.0
# 2              1.0

# %% [markdown]
# Je recombine

# %%
Xbase = pd.concat([Xquanti,XqualiD],axis=1)
dfbase = pd.concat([Xbase,Y],axis=1)
dfbase.to_csv("dfbase.csv",index=False)

# %% [markdown]
# Si je veux faire des polynomes

# %%
X2 = Xquanti**2
X2 = X2.add_suffix("car")
X3 = Xquanti**3
X3 = X3.add_suffix("cub")
Xpoly = pd.concat([Xbase,X2,X3],axis=1)
dfpoly = pd.concat([Xpoly,Y],axis=1)
print(dfpoly.head(3))
dfpoly.to_csv("dfpoly.csv",index=False)
# Out:
#    sbp  tobacco   ldl  adiposity  typea  obesity  alcohol  age  \
# 0  160    12.00  5.73      23.11     49    25.30    97.20   52
# 1  144     0.01  4.41      28.61     55    28.87     2.06   63
# 2  118     0.08  3.48      32.28     52    29.14     3.81   46
#
#    famhist_Present  sbpcar  ...  agecar   sbpcub   tobaccocub      ldlcub  \
# 0              1.0   25600  ...    2704  4096000  1728.000000  188.132517
# 1              0.0   20736  ...    3969  2985984     0.000001   85.766121
# 2              1.0   13924  ...    2116  1643032     0.000512   42.144192
#
#    adipositycub  typeacub    obesitycub     alcoholcub  agecub  Y
# 0  12342.406231    117649  16194.277000  918330.048000  140608  1
# 1  23418.203381    166375  24062.478103       8.741816  250047  1
# 2  33635.708352    140608  24743.927944      55.306341   97336  0
#
# [3 rows x 26 columns]

# %% [markdown]
# Si on veut faire des interactions plus compliqué, faire une boucle sur Xquanti sinon utiliser dmatrix de patsy

# %%
from patsy import dmatrix
nomvarexpl = list(don.columns.difference(["Y"]))
formule = "~" + "+".join(nomvarexpl)
dsX = dmatrix(formule,don,return_type="dataframe")
#je retire l'intercept
dsX = dsX.drop(columns=["Intercept"])
dfbase = pd.concat([dsX,Y],axis=1)
dfbase.to_csv("dfbase.csv",index=False)
dfbase.head(3)
# Out:
#    famhist[T.Present]  adiposity   age  alcohol   ldl  obesity    sbp  \
# 0                 1.0      23.11  52.0    97.20  5.73    25.30  160.0
# 1                 0.0      28.61  63.0     2.06  4.41    28.87  144.0
# 2                 1.0      32.28  46.0     3.81  3.48    29.14  118.0
#
#    tobacco  typea  Y
# 0    12.00   49.0  1
# 1     0.01   55.0  1
# 2     0.08   52.0  0

# %% [markdown]
# Si on veut faire l'intéraction

# %%
formuleI = "1 + (" + "+".join(nomvarexpl)+")**2"
Xinter = dmatrix(formuleI,don,return_type="dataframe")
#je retire l'intercept
Xinter = Xinter.drop(columns=["Intercept"])
dfinter = pd.concat([Xinter,Y],axis=1)
dfinter.to_csv("dfinter.csv",index=False)
dfinter.head(3)
# Out:
#    famhist[T.Present]  adiposity  adiposity:famhist[T.Present]   age  \
# 0                 1.0      23.11                         23.11  52.0
# 1                 0.0      28.61                          0.00  63.0
# 2                 1.0      32.28                         32.28  46.0
#
#    age:famhist[T.Present]  alcohol  alcohol:famhist[T.Present]   ldl  \
# 0                    52.0    97.20                       97.20  5.73
# 1                     0.0     2.06                        0.00  4.41
# 2                    46.0     3.81                        3.81  3.48
#
#    famhist[T.Present]:ldl  obesity  ...  ldl:sbp  ldl:tobacco  ldl:typea  \
# 0                    5.73    25.30  ...   916.80      68.7600     280.77
# 1                    0.00    28.87  ...   635.04       0.0441     242.55
# 2                    3.48    29.14  ...   410.64       0.2784     180.96
#
#    obesity:sbp  obesity:tobacco  obesity:typea  sbp:tobacco  sbp:typea  \
# 0      4048.00         303.6000        1239.70      1920.00     7840.0
# 1      4157.28           0.2887        1587.85         1.44     7920.0
# 2      3438.52           2.3312        1515.28         9.44     6136.0
#
#    tobacco:typea  Y
# 0         588.00  1
# 1           0.55  1
# 2           4.16  0
#
# [3 rows x 46 columns]
