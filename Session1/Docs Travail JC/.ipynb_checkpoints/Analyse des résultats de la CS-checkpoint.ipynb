# %% [markdown]
# # Analyse des résultats de la CS - Classification Supervisée

# %%
import pandas as pd; import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression, \
    LogisticRegressionCV
from sklearn.pipeline import Pipeline
from sklearn.model_selection import StratifiedKFold
import sklearn.metrics as sklm
from patsy import dmatrix

import sys
sys.path.append('../modules')
import logistic_step_sk as lss
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 13
#      11 import sys
#      12 sys.path.append('../modules')
# ---> 13 import logistic_step_sk as lss
#
# ModuleNotFoundError: No module named 'logistic_step_sk'

# %%
PROB = pd.read_csv("PROB.csv", header=0,  sep=",")
