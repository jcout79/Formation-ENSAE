# %% [markdown]
# # Notebook 1 : Découverte de Pandas

# %%
import pandas as pd

# %% [markdown]
# ## Iris

# %% [markdown]
# Nous considérons le jeu de données connu sous le nom des [Iris de Fisher](https://fr.wikipedia.org/wiki/Iris_de_Fisher). Répondez aux questions suivantes à l'aide du module Pandas.

# %% [markdown]
# 1. Charger le jeu de données dans un dataframe `iris` à partir du fichier `iris.csv` et afficher le dataframe.

# %%
import pandas as pd
df = pd.read_csv("../data/iris.csv")
df.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth Species
# 0          5.1         3.5          1.4         0.2  setosa
# 1          4.9         3.0          1.4         0.2  setosa
# 2          4.7         3.2          1.3         0.2  setosa
# 3          4.6         3.1          1.5         0.2  setosa
# 4          5.0         3.6          1.4         0.2  setosa

# %% [markdown]
# 2. Sélectionner les variables `PetalWidth` et `Species`.

# %%
print(df[["PetalWidth", "Species"]])
# Out:
#      PetalWidth    Species
# 0           0.2     setosa
# 1           0.2     setosa
# 2           0.2     setosa
# 3           0.2     setosa
# 4           0.2     setosa
# ..          ...        ...
# 145         2.3  virginica
# 146         1.9  virginica
# 147         2.0  virginica
# 148         2.3  virginica
# 149         1.8  virginica
#
# [150 rows x 2 columns]

# %% [markdown]
# 3. Extraire le sous-dataframe qui contient uniquement les iris des espèces `versicolor` ou `virginica`.

# %%
print(df[(df["Species"] == "virginica") | (df["Species"] == "setosa") ])
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth    Species
# 0            5.1         3.5          1.4         0.2     setosa
# 1            4.9         3.0          1.4         0.2     setosa
# 2            4.7         3.2          1.3         0.2     setosa
# 3            4.6         3.1          1.5         0.2     setosa
# 4            5.0         3.6          1.4         0.2     setosa
# ..           ...         ...          ...         ...        ...
# 145          6.7         3.0          5.2         2.3  virginica
# 146          6.3         2.5          5.0         1.9  virginica
# 147          6.5         3.0          5.2         2.0  virginica
# 148          6.2         3.4          5.4         2.3  virginica
# 149          5.9         3.0          5.1         1.8  virginica
#
# [100 rows x 5 columns]

# %% [markdown]
# 4. Compter le nombre d'iris de l'espèce `setosa`.

# %%
# df[df["Species"] == "setosa"].count()
len(df[df["Species"] == "setosa"])
# Out:
# 50

# %% [markdown]
# 5. Calculer la moyenne de la variable `PetalWidth` pour les iris de l'espèce `versicolor`.

# %%
df[df["Species"] == "versicolor"]["PetalWidth"].mean()
# Out:
# np.float64(1.3259999999999998)

# %% [markdown]
# 6. Ajouter une variable `SumWidth` qui contient la somme des variables `PetalWidth` et `SepalWidth`.

# %%
df["Sumwidth"] = df.PetalWidth + df.SepalWidth

# %% [markdown]
# 7. Calculer la moyenne et la variance de la variable `SepalLength` pour chaque espèce.

# %%
df[["SepalLength"]].groupby(df.Species).agg(["mean", "var"])
# Out:
#            SepalLength
#                   mean       var
# Species
# setosa           5.006  0.124249
# versicolor       5.936  0.266433
# virginica        6.588  0.404343

# %% [markdown]
# 8. Calculer la moyenne de toutes les variables pour chaque espèce. Afficher le résultat au format large et au format long.

# %%
moy = df[["SepalLength", "SepalWidth", "PetalLength", "PetalWidth"]].groupby(df.Species).mean()
#transformation format long
print(
    moy.reset_index()
    .melt(id_vars = ["Species"], value_name = "measure")
)
# Out:
#        Species     variable  measure
# 0       setosa  SepalLength    5.006
# 1   versicolor  SepalLength    5.936
# 2    virginica  SepalLength    6.588
# 3       setosa   SepalWidth    3.428
# 4   versicolor   SepalWidth    2.770
# 5    virginica   SepalWidth    2.974
# 6       setosa  PetalLength    1.462
# 7   versicolor  PetalLength    4.260
# 8    virginica  PetalLength    5.552
# 9       setosa   PetalWidth    0.246
# 10  versicolor   PetalWidth    1.326
# 11   virginica   PetalWidth    2.026

# %% [markdown]
# ## Houston flights

# %% [markdown]
# Nous considérons le jeux de données `hflights` relatif à des vols au départ des aéroports *Houston George Bush Intercontinental Airport* (IAH) et *William P. Hobby Airport* (HOU).

# %% [markdown]
# 1. Charger le jeu de données dans un dataframe `hflights` à partir du fichier `hflights.csv`

# %%
hflights = pd.read_csv("../data/hflights.csv")

# %% [markdown]
# 2. Sélectionner les variable `Dest`, `Distance`, `TaxiIn` et `TaxiOut` avec la méthode `filter`.

# %%
hflights.filter(items = ["Dest", "Distance", "TaxiIn", "TaxiOut"])
# items : facultatif, pour mentionner qu'on cible les colonnes

# avec expression régulière
hflights.filter(regex="^(D.st|Taxi)")
# Out:
#        Dest  Distance  TaxiIn  TaxiOut
# 0       DFW       224     7.0     13.0
# 1       DFW       224     6.0      9.0
# 2       DFW       224     5.0     17.0
# 3       DFW       224     9.0     22.0
# 4       DFW       224     9.0      9.0
# ...     ...       ...     ...      ...
# 227491  TPA       781     5.0     11.0
# 227492  TPA       781     4.0      9.0
# 227493  TUL       453     4.0     14.0
# 227494  TUL       453     3.0      9.0
# 227495  TUL       453     3.0     11.0
#
# [227496 rows x 4 columns]

# %% [markdown]
# 3. Sélectionner les variables `DepTime`, `ArrTime`, `ActualElapsedTime` et `AirTime` avec la méthode `filter` et le paramètre `like`.

# %%
hflights.filter(like = "Time")
# Out:
#         DepTime  ArrTime  ActualElapsedTime  AirTime
# 0        1400.0   1500.0               60.0     40.0
# 1        1401.0   1501.0               60.0     45.0
# 2        1352.0   1502.0               70.0     48.0
# 3        1403.0   1513.0               70.0     39.0
# 4        1405.0   1507.0               62.0     44.0
# ...         ...      ...                ...      ...
# 227491   1818.0   2111.0              113.0     97.0
# 227492   2047.0   2334.0              107.0     94.0
# 227493    912.0   1031.0               79.0     61.0
# 227494    656.0    812.0               76.0     64.0
# 227495   1600.0   1713.0               73.0     59.0
#
# [227496 rows x 4 columns]

# %% [markdown]
# 4. Ajouter une variable `ActualGroundTime` qui correspond à `ActualElapsedTime` moins `AirTime`.

# %%
hflights["ActualGroundTime"] = hflights.ActualElapsedTime - hflights.AirTime
# ActualElapsedTime : temps total
# Airtime : temps en l'air
# ActualGroundTime : temps au sol
hflights.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  ArrTime UniqueCarrier  \
# 0  2011      1           1          6   1400.0   1500.0            AA
# 1  2011      1           2          7   1401.0   1501.0            AA
# 2  2011      1           3          1   1352.0   1502.0            AA
# 3  2011      1           4          2   1403.0   1513.0            AA
# 4  2011      1           5          3   1405.0   1507.0            AA
#
#    FlightNum TailNum  ActualElapsedTime  ...  DepDelay  Origin  Dest Distance  \
# 0        428  N576AA               60.0  ...       0.0     IAH   DFW      224
# 1        428  N557AA               60.0  ...       1.0     IAH   DFW      224
# 2        428  N541AA               70.0  ...      -8.0     IAH   DFW      224
# 3        428  N403AA               70.0  ...       3.0     IAH   DFW      224
# 4        428  N492AA               62.0  ...       5.0     IAH   DFW      224
#
#   TaxiIn  TaxiOut  Cancelled  CancellationCode  Diverted ActualGroundTime
# 0    7.0     13.0          0               NaN         0             20.0
# 1    6.0      9.0          0               NaN         0             15.0
# 2    5.0     17.0          0               NaN         0             22.0
# 3    9.0     22.0          0               NaN         0             31.0
# 4    9.0      9.0          0               NaN         0             18.0
#
# [5 rows x 22 columns]

# %% [markdown]
# 5. Ajouter une variable `AverageSpeed` qui donne la vitesse moyenne du vol et ordonner la table selon les valeurs décroissantes de cette variable.

# %%
hflights["AverageSpeed"] = hflights.Distance / (hflights.AirTime)
hflights.sort_values(by = "AverageSpeed", ascending=False)
# Out:
#         Year  Month  DayofMonth  DayOfWeek  DepTime  ArrTime UniqueCarrier  \
# 147589  2011      8          31          3   1255.0   1346.0            CO
# 8318    2011      1           8          6   1620.0   1730.0            EV
# 34761   2011      2          21          1    834.0   1156.0            US
# 185953  2011     10           9          7   1104.0   1117.0            XE
# 40764   2011      3           9          3   1905.0   2225.0            CO
# ...      ...    ...         ...        ...      ...      ...           ...
# 227134  2011     12           4          7   1050.0   1843.0            WN
# 227153  2011     12           4          7      NaN      NaN            WN
# 227271  2011     12           5          1      NaN      NaN            WN
# 227302  2011     12           5          1    819.0   1221.0            WN
# 227394  2011     12           6          2      NaN      NaN            WN
#
#         FlightNum TailNum  ActualElapsedTime  ...  Dest  Distance  TaxiIn  \
# 147589       1646  N11612               51.0  ...   AUS       140     8.0
# 8318         5229  N451CA               70.0  ...   MEM       469    10.0
# 34761         944  N409US              142.0  ...   CLT       913    22.0
# 185953       4634  N11121               73.0  ...   HOB       501    13.0
# 40764         500  N19638              140.0  ...   IND       845     6.0
# ...           ...     ...                ...  ...   ...       ...     ...
# 227134       1797  N791SW                NaN  ...   BWI      1246     6.0
# 227153       2387  N928WN                NaN  ...   DAL       239     NaN
# 227271         38  N604SW                NaN  ...   DAL       239     NaN
# 227302        269  N665WN                NaN  ...   JAN       359     6.0
# 227394         16  N362SW                NaN  ...   DAL       239     NaN
#
#        TaxiOut Cancelled  CancellationCode  Diverted  ActualGroundTime  \
# 147589    32.0         0               NaN         0              40.0
# 8318      18.0         0               NaN         0              28.0
# 34761     35.0         0               NaN         0              57.0
# 185953    13.0         0               NaN         0              26.0
# 40764     52.0         0               NaN         0              58.0
# ...        ...       ...               ...       ...               ...
# 227134    11.0         0               NaN         1               NaN
# 227153     NaN         1                 A         0               NaN
# 227271     NaN         1                 A         0               NaN
# 227302     9.0         0               NaN         1               NaN
# 227394     NaN         1                 A         0               NaN
#
#             Speed AverageSpeed
# 147589   1.538462    12.727273
# 8318     4.263636    11.166667
# 34761    2.835404    10.741176
# 185953  38.538462    10.659574
# 40764    2.640625    10.304878
# ...           ...          ...
# 227134   1.571248          NaN
# 227153        NaN          NaN
# 227271        NaN          NaN
# 227302   0.893035          NaN
# 227394        NaN          NaN
#
# [227496 rows x 24 columns]

# %% [markdown]
# 6. Sélectionner les vols à destination de `JFK`.

# %%
hflights[hflights["Dest"] == "JFK"]
# Out:
#         Year  Month  DayofMonth  DayOfWeek  DepTime  ArrTime UniqueCarrier  \
# 304     2011      1           1          6    654.0   1124.0            B6
# 305     2011      1           1          6   1639.0   2110.0            B6
# 306     2011      1           2          7    703.0   1113.0            B6
# 307     2011      1           2          7   1604.0   2040.0            B6
# 308     2011      1           3          1    659.0   1100.0            B6
# ...      ...    ...         ...        ...      ...      ...           ...
# 208752  2011     12          29          4   1541.0   1959.0            B6
# 208753  2011     12          30          5    634.0   1040.0            B6
# 208754  2011     12          30          5   1541.0   1957.0            B6
# 208755  2011     12          31          6    831.0   1251.0            B6
# 208756  2011     12          31          6   1544.0   2009.0            B6
#
#         FlightNum TailNum  ActualElapsedTime  ...  Dest  Distance  TaxiIn  \
# 304           620  N324JB              210.0  ...   JFK      1428     6.0
# 305           622  N324JB              211.0  ...   JFK      1428    12.0
# 306           620  N324JB              190.0  ...   JFK      1428     6.0
# 307           622  N324JB              216.0  ...   JFK      1428     9.0
# 308           620  N229JB              181.0  ...   JFK      1428     3.0
# ...           ...     ...                ...  ...   ...       ...     ...
# 208752        622  N206JB              198.0  ...   JFK      1428     7.0
# 208753        620  N317JB              186.0  ...   JFK      1428     4.0
# 208754        622  N296JB              196.0  ...   JFK      1428     5.0
# 208755        620  N247JB              200.0  ...   JFK      1428     5.0
# 208756        622  N323JB              205.0  ...   JFK      1428     4.0
#
#        TaxiOut Cancelled  CancellationCode  Diverted  ActualGroundTime  \
# 304       23.0         0               NaN         0              29.0
# 305       11.0         0               NaN         0              23.0
# 306       12.0         0               NaN         0              18.0
# 307       31.0         0               NaN         0              40.0
# 308       12.0         0               NaN         0              15.0
# ...        ...       ...               ...       ...               ...
# 208752     8.0         0               NaN         0              15.0
# 208753    12.0         0               NaN         0              16.0
# 208754    10.0         0               NaN         0              15.0
# 208755    20.0         0               NaN         0              25.0
# 208756    11.0         0               NaN         0              15.0
#
#            Speed AverageSpeed
# 304     3.038298     7.889503
# 305     3.031847     7.595745
# 306     3.482927     8.302326
# 307     3.275229     8.113636
# 308     3.238095     8.602410
# ...          ...          ...
# 208752  3.416268     7.803279
# 208753  3.517241     8.400000
# 208754  3.432692     7.889503
# 208755  3.400000     8.160000
# 208756  3.070968     7.515789
#
# [695 rows x 24 columns]

# %% [markdown]
# 7. Compter le nombre de vols à destination de `JFK`.

# %%
len(hflights[hflights["Dest"] == "JFK"])
# Out:
# 695

# %% [markdown]
# 8. Agréger les données `hflights` pour obtenir :
# - `n` : le nombre total de vols,
# - `n_dest`: le nombre total de destinations distinctes,
# - `n_carrier` : le nombre total de compagnies distinctes.

# %%
# Méthode simple :
hflights.agg(
    {
        "FlightNum" : "count", 
        "Dest" : pd.Series.unique, 
        "UniqueCarrier" : pd.Series.unique
    }
    )
# Out:
# FlightNum                                                   227496
# Dest             [DFW, MIA, SEA, JFK, HNL, MSY, SAT, AUS, LAX, ...
# UniqueCarrier    [AA, AS, B6, CO, DL, OO, UA, US, WN, EV, F9, F...
# dtype: object

# %%
# Méthode plus jolie :
hflights.agg( 
    n = pd.NamedAgg(column="FlightNum", aggfunc = "count"),
    n_dest = pd.NamedAgg(column="Dest", aggfunc = "nunique"),
    n_carrier = pd.NamedAgg(column="UniqueCarrier", aggfunc = "nunique")
)
# Out:
#            FlightNum   Dest  UniqueCarrier
# n           227496.0    NaN            NaN
# n_dest           NaN  116.0            NaN
# n_carrier        NaN    NaN           15.0

# %% [markdown]
# 9. Agréger les données des vols de la compagnie `AA` pour obtenir :
# - le nombre total de vols,
# - le nombre total de vols annulés,
# - la valeur moyenne de `ArrDelay`.

# %%
hflights[hflights["UniqueCarrier"] == "AA"].agg(
    {
        "FlightNum"
    }
)

# %% [markdown]
# 10. Calculer pour chaque compagnie :
# - le nombre total de vols,
# - la valeur moyenne de `AirTime`.

# %% [markdown]
# 11. Ordonner les compagnies en fonction des retards moyens au départ.

# %%
(
    hflights
    .groupby("UniqueCarrier")
    .agg({"DepDelay" : "mean"})
    .sort_values(by = "DepDelay")
)
# Out:
#                 DepDelay
# UniqueCarrier
# YV              1.538462
# US              1.622926
# AS              3.712329
# FL              4.716376
# F9              5.093637
# AA              6.390144
# XE              7.713728
# OO              8.885482
# CO              9.261313
# DL              9.370627
# MQ             11.071745
# EV             12.482193
# UA             12.918707
# B6             13.320532
# WN             13.488241
